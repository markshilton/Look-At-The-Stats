# %%
import pandas as pd
import numpy as np
import json
import datetime
import time

def parse_time(raw_time):
    '''Parse the raw time strings into timedeltas for doing arithmetic on the times'''
    if raw_time == '':
        return None
    else:
        try:
            dt = datetime.datetime.strptime(raw_time, '%M:%S.%f')
            timedelta = datetime.timedelta(minutes=dt.minute, seconds=dt.second, microseconds=dt.microsecond)
            return timedelta
        except:
            dt = datetime.datetime.strptime(raw_time, '%S.%f')
            timedelta = datetime.timedelta(seconds=dt.second, microseconds=dt.microsecond)
            return timedelta


def timedeltaToString(rawTd):
    '''Convert timedelta to a MM:SS.000 formatted string'''
    try:
        dt = pd.to_datetime(rawTd)
        dt = datetime.datetime.strftime(dt, '%M:%S.%f')[:-3] #Returns time down to nanoseconds. This just strips off the last three zeros
        return dt
    except:
        return None
    
with open('seasonData.json', 'r') as jsonFile:
    seasonData = json.load(jsonFile)
    
#Just grabbing a single set of results for now. Will create a loop to do the whole lot later...    
df = pd.DataFrame.from_dict(seasonData[0]['results'][0]['categoryResults'])

#Apply the time parser to the raw times
for i in range(1,4):
    df['sector' + str(i)] = df['sector' + str(i)].apply(parse_time)

#Calculate the total split times for each split
df['split1'] = df['sector1']
df['split2'] = df['sector1'] + df['sector2']
df['split3'] = df['split2'] + df['sector3']
df.head()

#Calculate the time gaps and rankings for everything
cols = ['sector1', 'sector2', 'sector3', 'split1', 'split2', 'split3']

for col in cols:
    df[col + 'Gap'] = df[col].apply(lambda x: (x - df[col].min())/np.timedelta64(1,'s'))
    df[col + 'Rank'] = df[col].rank()
    df[col] = df[col].apply(timedeltaToString)

df.head()
# Out:
#   finishTime            name position    sector1    sector2    sector3  \
# 0   3:59.344      Aaron GWIN        1  01:55.307  01:26.282  00:37.755
# 1   4:01.381  Michael HANNAH        2  01:58.346  01:25.624  00:37.411
# 2   4:02.168    Greg MINNAAR        3  01:56.941  01:26.154  00:39.073
# 3   4:02.237      Loic BRUNI        4  01:55.607  01:28.774  00:37.856
# 4   4:02.675    Troy BROSNAN        5  01:56.466  01:27.777  00:38.432
#
#       split1     split2     split3  sector1Gap     ...      sector2Gap  \
# 0  01:55.307  03:21.589  03:59.344       0.000     ...           0.658
# 1  01:58.346  03:23.970  04:01.381       3.039     ...           0.000
# 2  01:56.941  03:23.095  04:02.168       1.634     ...           0.530
# 3  01:55.607  03:24.381  04:02.237       0.300     ...           3.150
# 4  01:56.466  03:24.243  04:02.675       1.159     ...           2.153
#
#    sector2Rank  sector3Gap  sector3Rank  split1Gap  split1Rank  split2Gap  \
# 0            3       0.344            2      0.000           1      0.000
# 1            1       0.000            1      3.039          10      2.381
# 2            2       1.662           11      1.634           4      1.506
# 3           12       0.445            4      0.300           2      2.792
# 4            6       1.021            6      1.159           3      2.654
#
#    split2Rank  split3Gap  split3Rank
# 0           1      0.000           1
# 1           3      2.037           2
# 2           2      2.824           3
# 3           5      2.893           4
# 4           4      3.331           5
#
# [5 rows x 21 columns]

# %%
for race in range(0,len(seasonData)):
    for cat in range(0,2):
        print('processing ' + str(seasonData[race]['venue']) + ' ' + str(seasonData[race]['results'][cat]['category']))
# Out:
# processing Pietermaritzburg Men
# processing Pietermaritzburg Women
# processing Cairns Men
# processing Cairns Women
# processing Fort William Men
# processing Fort William Women
# processing Leogang Men
# processing Leogang Women
# processing Mont Sainte-Anne Men
# processing Mont Sainte-Anne Women
# processing Windham Men
# processing Windham Women
# processing Meribel Men
# processing Meribel Women
# processing Hafjell Men
# processing Hafjell Women

# %%
for i in range(0,len(seasonData)):
    race = seasonData[i]
    for cat in range(0,2):
        
    print(seasonData[i]['venue'])
